# %%
import json
from os import environ
import requests
import time

from dotenv import load_dotenv
import polars as pl

# %%
load_dotenv()
# Out:
# True

# %%
def query_nyt(year: int, month: int):   
    if len(str(year)) != 4:
           raise ValueError
    
    if month not in range(0, 13):
        raise ValueError
        
    url = f"https://api.nytimes.com/svc/archive/v1/{year}/{month}.json?api-key={environ['NYT_KEY']}"
    
    return requests.get(url).json()

# %%
articles = query_nyt(2022, 1)['response']['docs']

# %%
kws = [{'keywords': a['keywords']} for a in articles]

# %%
pl.from_dicts(kws)
# Out:
# shape: (3799, 1)
# ┌─────────────────────────────────────┐
# │ keywords                            │
# │ ---                                 │
# │ list[struct[4]]                     │
# ╞═════════════════════════════════════╡
# │ [{"subject","Football (College)"... │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ [{"persons","White, Betty",1,"N"... │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ [{"persons","White, Betty",1,"N"... │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ [{"subject","Crossword Puzzles",... │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ ...                                 │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ [{"persons","Chew, Troy Lamarr I... │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ [{"organizations","North Atlanti... │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ [{"subject","News and News Media... │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ [{"subject","Embargoes and Sanct... │
# └─────────────────────────────────────┘
